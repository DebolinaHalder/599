# %%
import numpy as np
import pandas as pd
from fairforest import d_tree
from fairforest import utils
import warnings

# %%
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("dataset/adult.csv")
df = df[0:1000]
target = df['income-per-year'].to_numpy()
df = df.drop('income-per-year',1)
target = np.where(target == -1, 0, target)

# %%
model_dtree = d_tree.DecisionTree(4,0)
model_dtree.fit(df,target)
# Out:
# build tree for node  0
# spliting
# spliting done
# marital-status=Married-civ-spouse 0.5
# build tree for node  1
# spliting
# spliting done
# capital-gain 7731.5
# build tree for node  3
# spliting
# spliting done
# education-num 12.5
# build tree for node  5
# spliting
# spliting done
# age 38.5
# build tree for node  7
# only one class for this node
# build tree for node  8
# spliting
# spliting done
# occupation=Craft-repair 0.5
# build tree for node  9
# spliting
# spliting done
# workclass=State-gov 0.5
# build tree for node  11
# spliting
# spliting done
# occupation=Adm-clerical 0.5
# build tree for node  13
# only one class for this node
# build tree for node  14
# spliting
# spliting done
# age 39.5
# build tree for node  15
# only one class for this node
# build tree for node  16
# spliting
# spliting done
# age 62.0
# build tree for node  17
# only one class for this node
# build tree for node  18
# spliting
# spliting done
# age 65.5
# build tree for node  19
# only one class for this node
# build tree for node  20
# only one class for this node
# build tree for node  12
# spliting
# spliting done
# sex 0.5
# build tree for node  21
# only one class for this node
# build tree for node  22
# only one class for this node
# build tree for node  10
# spliting
# spliting done
# age 43.0
# build tree for node  23
# only one class for this node
# build tree for node  24
# spliting
# spliting done
# hours-per-week 46.0
# build tree for node  25
# only one class for this node
# build tree for node  26
# only one class for this node
# build tree for node  6
# spliting
# spliting done
# age 35.5
# build tree for node  27
# spliting
# spliting done
# capital-loss 2160.0
# build tree for node  29
# spliting
# spliting done
# hours-per-week 47.5
# build tree for node  31
# only one class for this node
# build tree for node  32
# spliting
# spliting done
# occupation=Prof-specialty 0.5
# build tree for node  33
# only one class for this node
# build tree for node  34
# spliting
# spliting done
# hours-per-week 52.5
# build tree for node  35
# only one class for this node
# build tree for node  36
# only one class for this node
# build tree for node  30
# only one class for this node
# build tree for node  28
# spliting
# spliting done
# age 40.0
# build tree for node  37
# spliting
# spliting done
# education-num 13.5
# build tree for node  39
# spliting
# spliting done
# age 38.5
# build tree for node  41
# spliting
# spliting done
# age 37.5
# build tree for node  43
# spliting
# spliting done
# race 0.5
# build tree for node  45
# only one class for this node
# build tree for node  46
# spliting
# spliting done
# hours-per-week 47.5
# build tree for node  47
# only one class for this node
# build tree for node  48
# only one class for this node
# build tree for node  44
# only one class for this node
# build tree for node  42
# only one class for this node
# build tree for node  40
# only one class for this node
# build tree for node  38
# spliting
# spliting done
# capital-gain 2467.0
# build tree for node  49
# spliting
# spliting done
# education-num 15.5
# build tree for node  51
# spliting
# spliting done
# hours-per-week 51.0
# build tree for node  53
# spliting
# spliting done
# relationship=Other-relative 0.5
# build tree for node  55
# spliting
# spliting done
# workclass=Federal-gov 0.5
# build tree for node  57
# spliting
# spliting done
# occupation=Sales 0.5
# build tree for node  59
# only one class for this node
# build tree for node  60
# spliting
# spliting done
# age 42.0
# build tree for node  61
# only one class for this node
# build tree for node  62
# spliting
# spliting done
# age 52.0
# build tree for node  63
# only one class for this node
# build tree for node  64
# only one class for this node
# build tree for node  58
# spliting
# spliting done
# age 56.5
# build tree for node  65
# only one class for this node
# build tree for node  66
# only one class for this node
# build tree for node  56
# only one class for this node
# build tree for node  54
# spliting
# spliting done
# hours-per-week 77.5
# build tree for node  67
# only one class for this node
# build tree for node  68
# only one class for this node
# build tree for node  52
# spliting
# spliting done
# age 59.0
# build tree for node  69
# only one class for this node
# build tree for node  70
# only one class for this node
# build tree for node  50
# only one class for this node
# build tree for node  4
# only one class for this node
# build tree for node  2
# spliting
# spliting done
# capital-gain 5095.5
# build tree for node  71
# spliting
# spliting done
# education-num 9.5
# build tree for node  73
# spliting
# spliting done
# hours-per-week 49.0
# build tree for node  75
# spliting
# spliting done
# capital-loss 1757.5
# build tree for node  77
# spliting
# spliting done
# education-num 8.5
# build tree for node  79
# spliting
# spliting done
# native-country=El-Salvador 0.5
# build tree for node  81
# spliting
# spliting done
# occupation=Transport-moving 0.5
# build tree for node  83
# only one class for this node
# build tree for node  84
# spliting
# spliting done
# education-num 6.5
# build tree for node  85
# only one class for this node
# build tree for node  86
# only one class for this node
# build tree for node  82
# only one class for this node
# build tree for node  80
# spliting
# spliting done
# hours-per-week 36.5
# build tree for node  87
# only one class for this node
# build tree for node  88
# spliting
# spliting done
# workclass=Self-emp-inc 0.5
# build tree for node  89
# spliting
# spliting done
# age 53.5
# build tree for node  91
# spliting
# spliting done
# age 48.5
# build tree for node  93
# spliting
# spliting done
# workclass=Federal-gov 0.5
# build tree for node  95
# spliting
# spliting done
# occupation=Exec-managerial 0.5
# build tree for node  97
# spliting
# spliting done
# occupation=Adm-clerical 0.5
# build tree for node  99
# spliting
# spliting done
# age 40.5
# build tree for node  101
# spliting
# spliting done
# occupation=Tech-support 0.5
# build tree for node  103
# spliting
# spliting done
# sex 0.5
# build tree for node  105
# only one class for this node
# build tree for node  106
# spliting
# spliting done
# occupation=Sales 0.5
# build tree for node  107
# spliting
# spliting done
# hours-per-week 39.0
# build tree for node  109
# only one class for this node
# build tree for node  110
# spliting
# spliting done
# age 25.5
# build tree for node  111
# only one class for this node
# build tree for node  112
# spliting
# spliting done
# age 29.5
# build tree for node  113
# only one class for this node
# build tree for node  114
# spliting
# spliting done
# age 37.5
# build tree for node  115
# spliting
# spliting done
# occupation=Craft-repair 0.5
# build tree for node  117
# only one class for this node
# build tree for node  118
# spliting
# spliting done
# age 34.5
# build tree for node  119
# only one class for this node
# build tree for node  120
# only one class for this node
# build tree for node  116
# spliting
# spliting done
# native-country=Mexico 0.5
# build tree for node  121
# spliting
# spliting done
# occupation=Craft-repair 0.5
# build tree for node  123
# only one class for this node
# build tree for node  124
# spliting
# spliting done
# age 39.0
# build tree for node  125
# only one class for this node
# build tree for node  126
# spliting
# spliting done
# None None
# build tree for node  122
# only one class for this node
# build tree for node  108
# spliting
# spliting done
# age 32.5
# build tree for node  128
# spliting
# spliting done
# age 27.5
# build tree for node  130
# only one class for this node
# build tree for node  131
# only one class for this node
# build tree for node  129
# only one class for this node
# build tree for node  104
# only one class for this node
# build tree for node  102
# spliting
# spliting done
# capital-gain 1551.5
# build tree for node  132
# only one class for this node
# build tree for node  133
# only one class for this node
# build tree for node  100
# spliting
# spliting done
# relationship=Wife 0.5
# build tree for node  134
# only one class for this node
# build tree for node  135
# only one class for this node
# build tree for node  98
# spliting
# spliting done
# age 39.0
# build tree for node  136
# only one class for this node
# build tree for node  137
# only one class for this node
# build tree for node  96
# only one class for this node
# build tree for node  94
# only one class for this node
# build tree for node  92
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  138
# spliting
# spliting done
# age 61.5
# build tree for node  140
# spliting
# spliting done
# age 56.5
# build tree for node  142
# spliting
# spliting done
# sex 0.5
# build tree for node  144
# only one class for this node
# build tree for node  145
# spliting
# spliting done
# occupation=Handlers-cleaners 0.5
# build tree for node  146
# only one class for this node
# build tree for node  147
# only one class for this node
# build tree for node  143
# only one class for this node
# build tree for node  141
# spliting
# spliting done
# race 0.5
# build tree for node  148
# only one class for this node
# build tree for node  149
# only one class for this node
# build tree for node  139
# only one class for this node
# build tree for node  90
# only one class for this node
# build tree for node  78
# spliting
# spliting done
# age 36.5
# build tree for node  150
# only one class for this node
# build tree for node  151
# only one class for this node
# build tree for node  76
# spliting
# spliting done
# workclass=Self-emp-not-inc 0.5
# build tree for node  152
# spliting
# spliting done
# age 57.0
# build tree for node  154
# spliting
# spliting done
# age 41.5
# build tree for node  156
# spliting
# spliting done
# occupation=Transport-moving 0.5
# build tree for node  158
# spliting
# spliting done
# age 36.5
# build tree for node  160
# spliting
# spliting done
# hours-per-week 70.0
# build tree for node  162
# spliting
# spliting done
# occupation=Craft-repair 0.5
# build tree for node  164
# spliting
# spliting done
# education-num 8.0
# build tree for node  166
# only one class for this node
# build tree for node  167
# only one class for this node
# build tree for node  165
# only one class for this node
# build tree for node  163
# only one class for this node
# build tree for node  161
# only one class for this node
# build tree for node  159
# only one class for this node
# build tree for node  157
# spliting
# spliting done
# hours-per-week 62.5
# build tree for node  168
# spliting
# spliting done
# education=7th-8th 0.5
# build tree for node  170
# only one class for this node
# build tree for node  171
# only one class for this node
# build tree for node  169
# spliting
# spliting done
# occupation=Transport-moving 0.5
# build tree for node  172
# only one class for this node
# build tree for node  173
# only one class for this node
# build tree for node  155
# spliting
# spliting done
# age 68.5
# build tree for node  174
# only one class for this node
# build tree for node  175
# only one class for this node
# build tree for node  153
# spliting
# spliting done
# age 38.0
# build tree for node  176
# spliting
# spliting done
# race 0.5
# build tree for node  178
# spliting
# spliting done
# age 36.0
# build tree for node  180
# only one class for this node
# build tree for node  181
# only one class for this node
# build tree for node  179
# only one class for this node
# build tree for node  177
# spliting
# spliting done
# age 57.5
# build tree for node  182
# only one class for this node
# build tree for node  183
# only one class for this node
# build tree for node  74
# spliting
# spliting done
# capital-loss 1782.5
# build tree for node  184
# spliting
# spliting done
# occupation=Prof-specialty 0.5
# build tree for node  186
# spliting
# spliting done
# education-num 13.5
# build tree for node  188
# spliting
# spliting done
# capital-gain 3120.0
# build tree for node  190
# spliting
# spliting done
# capital-gain 1551.5
# build tree for node  192
# spliting
# spliting done
# occupation=Sales 0.5
# build tree for node  194
# spliting
# spliting done
# education=Assoc-voc 0.5
# build tree for node  196
# spliting
# spliting done
# age 22.5
# build tree for node  198
# only one class for this node
# build tree for node  199
# spliting
# spliting done
# race 0.5
# build tree for node  200
# spliting
# spliting done
# native-country=United-States 0.5
# build tree for node  202
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  204
# only one class for this node
# build tree for node  205
# only one class for this node
# build tree for node  203
# spliting
# spliting done
# age 58.5
# build tree for node  206
# only one class for this node
# build tree for node  207
# only one class for this node
# build tree for node  201
# spliting
# spliting done
# hours-per-week 39.5
# build tree for node  208
# spliting
# spliting done
# age 26.0
# build tree for node  210
# only one class for this node
# build tree for node  211
# spliting
# spliting done
# hours-per-week 16.0
# build tree for node  212
# only one class for this node
# build tree for node  213
# spliting
# spliting done
# workclass=State-gov 0.5
# build tree for node  214
# only one class for this node
# build tree for node  215
# spliting
# spliting done
# age 46.5
# build tree for node  216
# only one class for this node
# build tree for node  217
# only one class for this node
# build tree for node  209
# spliting
# spliting done
# education=Assoc-acdm 0.5
# build tree for node  218
# spliting
# spliting done
# age 41.5
# build tree for node  220
# spliting
# spliting done
# age 34.5
# build tree for node  222
# spliting
# spliting done
# education-num 11.5
# build tree for node  224
# spliting
# spliting done
# native-country=United-States 0.5
# build tree for node  226
# only one class for this node
# build tree for node  227
# spliting
# spliting done
# age 30.0
# build tree for node  228
# spliting
# spliting done
# workclass=Self-emp-not-inc 0.5
# build tree for node  230
# spliting
# spliting done
# occupation=Protective-serv 0.5
# build tree for node  232
# only one class for this node
# build tree for node  233
# spliting
# spliting done
# age 25.5
# build tree for node  234
# only one class for this node
# build tree for node  235
# only one class for this node
# build tree for node  231
# only one class for this node
# build tree for node  229
# spliting
# spliting done
# hours-per-week 45.0
# build tree for node  236
# only one class for this node
# build tree for node  237
# only one class for this node
# build tree for node  225
# spliting
# spliting done
# age 28.5
# build tree for node  238
# only one class for this node
# build tree for node  239
# only one class for this node
# build tree for node  223
# spliting
# spliting done
# workclass=Self-emp-inc 0.5
# build tree for node  240
# spliting
# spliting done
# workclass=Self-emp-not-inc 0.5
# build tree for node  242
# spliting
# spliting done
# age 36.5
# build tree for node  244
# spliting
# spliting done
# education-num 11.5
# build tree for node  246
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  248
# only one class for this node
# build tree for node  249
# spliting
# spliting done
# age 35.5
# build tree for node  250
# only one class for this node
# build tree for node  251
# only one class for this node
# build tree for node  247
# only one class for this node
# build tree for node  245
# spliting
# spliting done
# workclass=Private 0.5
# build tree for node  252
# only one class for this node
# build tree for node  253
# spliting
# spliting done
# age 39.5
# build tree for node  254
# spliting
# spliting done
# occupation=Exec-managerial 0.5
# build tree for node  256
# spliting
# spliting done
# age 38.5
# build tree for node  258
# only one class for this node
# build tree for node  259
# spliting
# spliting done
# education-num 11.5
# build tree for node  260
# only one class for this node
# build tree for node  261
# only one class for this node
# build tree for node  257
# only one class for this node
# build tree for node  255
# only one class for this node
# build tree for node  243
# only one class for this node
# build tree for node  241
# only one class for this node
# build tree for node  221
# spliting
# spliting done
# age 44.5
# build tree for node  262
# spliting
# spliting done
# age 42.5
# build tree for node  264
# spliting
# spliting done
# education-num 11.5
# build tree for node  266
# only one class for this node
# build tree for node  267
# only one class for this node
# build tree for node  265
# only one class for this node
# build tree for node  263
# spliting
# spliting done
# workclass=Self-emp-inc 0.5
# build tree for node  268
# spliting
# spliting done
# occupation=Craft-repair 0.5
# build tree for node  270
# spliting
# spliting done
# workclass=State-gov 0.5
# build tree for node  272
# spliting
# spliting done
# hours-per-week 49.0
# build tree for node  274
# spliting
# spliting done
# age 45.5
# build tree for node  276
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  278
# only one class for this node
# build tree for node  279
# only one class for this node
# build tree for node  277
# only one class for this node
# build tree for node  275
# spliting
# spliting done
# age 49.5
# build tree for node  280
# only one class for this node
# build tree for node  281
# spliting
# spliting done
# age 55.5
# build tree for node  282
# only one class for this node
# build tree for node  283
# only one class for this node
# build tree for node  273
# only one class for this node
# build tree for node  271
# spliting
# spliting done
# workclass=State-gov 0.5
# build tree for node  284
# only one class for this node
# build tree for node  285
# only one class for this node
# build tree for node  269
# only one class for this node
# build tree for node  219
# only one class for this node
# build tree for node  197
# spliting
# spliting done
# age 30.5
# build tree for node  286
# spliting
# spliting done
# age 24.5
# build tree for node  288
# only one class for this node
# build tree for node  289
# spliting
# spliting done
# hours-per-week 68.0
# build tree for node  290
# only one class for this node
# build tree for node  291
# only one class for this node
# build tree for node  287
# only one class for this node
# build tree for node  195
# spliting
# spliting done
# education-num 11.5
# build tree for node  292
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  294
# only one class for this node
# build tree for node  295
# spliting
# spliting done
# hours-per-week 64.0
# build tree for node  296
# spliting
# spliting done
# hours-per-week 57.5
# build tree for node  298
# spliting
# spliting done
# age 32.5
# build tree for node  300
# only one class for this node
# build tree for node  301
# spliting
# spliting done
# age 39.0
# build tree for node  302
# only one class for this node
# build tree for node  303
# spliting
# spliting done
# age 47.0
# build tree for node  304
# only one class for this node
# build tree for node  305
# spliting
# spliting done
# age 52.0
# build tree for node  306
# only one class for this node
# build tree for node  307
# only one class for this node
# build tree for node  299
# only one class for this node
# build tree for node  297
# only one class for this node
# build tree for node  293
# only one class for this node
# build tree for node  193
# only one class for this node
# build tree for node  191
# only one class for this node
# build tree for node  189
# spliting
# spliting done
# occupation=Tech-support 0.5
# build tree for node  308
# spliting
# spliting done
# native-country=India 0.5
# build tree for node  310
# only one class for this node
# build tree for node  311
# only one class for this node
# build tree for node  309
# only one class for this node
# build tree for node  187
# spliting
# spliting done
# education-num 10.5
# build tree for node  312
# only one class for this node
# build tree for node  313
# spliting
# spliting done
# age 33.5
# build tree for node  314
# spliting
# spliting done
# education-num 12.5
# build tree for node  316
# only one class for this node
# build tree for node  317
# spliting
# spliting done
# age 26.0
# build tree for node  318
# spliting
# spliting done
# age 24.5
# build tree for node  320
# only one class for this node
# build tree for node  321
# spliting
# spliting done
# race 0.5
# build tree for node  322
# only one class for this node
# build tree for node  323
# only one class for this node
# build tree for node  319
# spliting
# spliting done
# hours-per-week 37.5
# build tree for node  324
# spliting
# spliting done
# sex 0.5
# build tree for node  326
# only one class for this node
# build tree for node  327
# only one class for this node
# build tree for node  325
# only one class for this node
# build tree for node  315
# spliting
# spliting done
# native-country=Canada 0.5
# build tree for node  328
# spliting
# spliting done
# hours-per-week 57.5
# build tree for node  330
# spliting
# spliting done
# age 37.5
# build tree for node  332
# only one class for this node
# build tree for node  333
# spliting
# spliting done
# age 38.5
# build tree for node  334
# spliting
# spliting done
# education-num 15.5
# build tree for node  336
# spliting
# spliting done
# sex 0.5
# build tree for node  338
# only one class for this node
# build tree for node  339
# only one class for this node
# build tree for node  337
# only one class for this node
# build tree for node  335
# spliting
# spliting done
# age 45.5
# build tree for node  340
# only one class for this node
# build tree for node  341
# spliting
# spliting done
# age 49.0
# build tree for node  342
# spliting
# spliting done
# workclass=Private 0.5
# build tree for node  344
# only one class for this node
# build tree for node  345
# only one class for this node
# build tree for node  343
# spliting
# spliting done
# education=Masters 0.5
# build tree for node  346
# only one class for this node
# build tree for node  347
# spliting
# spliting done
# hours-per-week 42.5
# build tree for node  348
# only one class for this node
# build tree for node  349
# only one class for this node
# build tree for node  331
# spliting
# spliting done
# age 39.0
# build tree for node  350
# only one class for this node
# build tree for node  351
# spliting
# spliting done
# age 55.5
# build tree for node  352
# only one class for this node
# build tree for node  353
# only one class for this node
# build tree for node  329
# only one class for this node
# build tree for node  185
# spliting
# spliting done
# hours-per-week 62.5
# build tree for node  354
# spliting
# spliting done
# education-num 15.5
# build tree for node  356
# only one class for this node
# build tree for node  357
# spliting
# spliting done
# age 47.0
# build tree for node  358
# only one class for this node
# build tree for node  359
# only one class for this node
# build tree for node  355
# only one class for this node
# build tree for node  72
# spliting
# spliting done
# age 66.5
# build tree for node  360
# only one class for this node
# build tree for node  361
# only one class for this node

# %%
feature_importance = model_dtree._feature_importance()

# %%
fairness_importance = model_dtree._fairness_importance()

# %%
for key, value in fairness_importance.items():
    print(key, value)
# Out:
# age -0.008962691025106205
# education-num 0.025027561713317756
# race -0.11475008900939179
# sex -0.2452721088435374
# capital-gain -0.025962739956016667
# capital-loss 0.15160466020856608
# hours-per-week -0.057524146707254885
# workclass=Federal-gov 0.21085960465331072
# workclass=Local-gov 0
# workclass=Private -0.2730555555555555
# workclass=Self-emp-inc -0.015510318908654655
# workclass=Self-emp-not-inc 0.1016427024429466
# workclass=State-gov 0.040119803936380705
# workclass=Without-pay 0
# education=10th 0
# education=11th 0
# education=12th 0
# education=1st-4th 0
# education=5th-6th 0
# education=7th-8th -0.17999999999999994
# education=9th 0
# education=Assoc-acdm -0.00215928472927851
# education=Assoc-voc 0.30255993443070817
# education=Bachelors 0
# education=Doctorate 0
# education=HS-grad 0
# education=Masters 0.2644444444444445
# education=Preschool 0
# education=Prof-school 0
# education=Some-college 0
# marital-status=Divorced 0
# marital-status=Married-AF-spouse 0
# marital-status=Married-civ-spouse 0.23362116557749146
# marital-status=Married-spouse-absent 0
# marital-status=Never-married 0
# marital-status=Separated 0
# marital-status=Widowed 0
# occupation=Adm-clerical 0.2937527594292942
# occupation=Armed-Forces 0
# occupation=Craft-repair 0.11463913145950522
# occupation=Exec-managerial 0.1479202284903478
# occupation=Farming-fishing 0
# occupation=Handlers-cleaners -0.375
# occupation=Machine-op-inspct 0
# occupation=Other-service 0
# occupation=Priv-house-serv 0
# occupation=Prof-specialty 0.33722598243241614
# occupation=Protective-serv 0.22222222222222232
# occupation=Sales 0.35585430824270503
# occupation=Tech-support -0.066351765121897
# occupation=Transport-moving -0.022150289999663064
# relationship=Husband 0
# relationship=Not-in-family 0
# relationship=Other-relative -0.05842222222222215
# relationship=Own-child 0
# relationship=Unmarried 0
# relationship=Wife -0.5
# native-country=Cambodia 0
# native-country=Canada -0.025661923184445712
# native-country=China 0
# native-country=Columbia 0
# native-country=Cuba 0
# native-country=Dominican-Republic 0
# native-country=Ecuador 0
# native-country=El-Salvador -0.032314562099776234
# native-country=England 0
# native-country=France 0
# native-country=Germany 0
# native-country=Greece 0
# native-country=Guatemala 0
# native-country=Haiti 0
# native-country=Holand-Netherlands 0
# native-country=Honduras 0
# native-country=Hong 0
# native-country=Hungary 0
# native-country=India -0.16528925619834722
# native-country=Iran 0
# native-country=Ireland 0
# native-country=Italy 0
# native-country=Jamaica 0
# native-country=Japan 0
# native-country=Laos 0
# native-country=Mexico 0.03555555555555556
# native-country=Nicaragua 0
# native-country=Outlying-US(Guam-USVI-etc) 0
# native-country=Peru 0
# native-country=Philippines 0
# native-country=Poland 0
# native-country=Portugal 0
# native-country=Puerto-Rico 0
# native-country=Scotland 0
# native-country=South 0
# native-country=Taiwan 0
# native-country=Thailand 0
# native-country=Trinadad&Tobago 0
# native-country=United-States 0.15159216234703254
# native-country=Vietnam 0
# native-country=Yugoslavia 0

# %%
for key, value in feature_importance.items():
    print(key, value)
# Out:
# age 0.008962691025106205
# education-num -0.025027561713317756
# race 0.11475008900939179
# sex 0.2452721088435374
# capital-gain 0.025962739956016667
# capital-loss -0.15160466020856608
# hours-per-week 0.057524146707254885
# workclass=Federal-gov -0.21085960465331072
# workclass=Local-gov 0
# workclass=Private 0.2730555555555555
# workclass=Self-emp-inc 0.015510318908654655
# workclass=Self-emp-not-inc -0.1016427024429466
# workclass=State-gov -0.040119803936380705
# workclass=Without-pay 0
# education=10th 0
# education=11th 0
# education=12th 0
# education=1st-4th 0
# education=5th-6th 0
# education=7th-8th 0.17999999999999994
# education=9th 0
# education=Assoc-acdm 0.00215928472927851
# education=Assoc-voc -0.30255993443070817
# education=Bachelors 0
# education=Doctorate 0
# education=HS-grad 0
# education=Masters -0.2644444444444445
# education=Preschool 0
# education=Prof-school 0
# education=Some-college 0
# marital-status=Divorced 0
# marital-status=Married-AF-spouse 0
# marital-status=Married-civ-spouse -0.23362116557749146
# marital-status=Married-spouse-absent 0
# marital-status=Never-married 0
# marital-status=Separated 0
# marital-status=Widowed 0
# occupation=Adm-clerical -0.2937527594292942
# occupation=Armed-Forces 0
# occupation=Craft-repair -0.11463913145950522
# occupation=Exec-managerial -0.1479202284903478
# occupation=Farming-fishing 0
# occupation=Handlers-cleaners 0.375
# occupation=Machine-op-inspct 0
# occupation=Other-service 0
# occupation=Priv-house-serv 0
# occupation=Prof-specialty -0.33722598243241614
# occupation=Protective-serv -0.22222222222222232
# occupation=Sales -0.35585430824270503
# occupation=Tech-support 0.066351765121897
# occupation=Transport-moving 0.022150289999663064
# relationship=Husband 0
# relationship=Not-in-family 0
# relationship=Other-relative 0.05842222222222215
# relationship=Own-child 0
# relationship=Unmarried 0
# relationship=Wife 0.5
# native-country=Cambodia 0
# native-country=Canada 0.025661923184445712
# native-country=China 0
# native-country=Columbia 0
# native-country=Cuba 0
# native-country=Dominican-Republic 0
# native-country=Ecuador 0
# native-country=El-Salvador 0.032314562099776234
# native-country=England 0
# native-country=France 0
# native-country=Germany 0
# native-country=Greece 0
# native-country=Guatemala 0
# native-country=Haiti 0
# native-country=Holand-Netherlands 0
# native-country=Honduras 0
# native-country=Hong 0
# native-country=Hungary 0
# native-country=India 0.16528925619834722
# native-country=Iran 0
# native-country=Ireland 0
# native-country=Italy 0
# native-country=Jamaica 0
# native-country=Japan 0
# native-country=Laos 0
# native-country=Mexico -0.03555555555555556
# native-country=Nicaragua 0
# native-country=Outlying-US(Guam-USVI-etc) 0
# native-country=Peru 0
# native-country=Philippines 0
# native-country=Poland 0
# native-country=Portugal 0
# native-country=Puerto-Rico 0
# native-country=Scotland 0
# native-country=South 0
# native-country=Taiwan 0
# native-country=Thailand 0
# native-country=Trinadad&Tobago 0
# native-country=United-States -0.15159216234703254
# native-country=Vietnam 0
# native-country=Yugoslavia 0

# %%
for key, value in model_dtree.feature.items():
    print(key, value)
# Out:
# 0 marital-status=Married-civ-spouse
# 1 capital-gain
# 3 education-num
# 5 age
# 7 -2
# 8 occupation=Craft-repair
# 9 workclass=State-gov
# 11 occupation=Adm-clerical
# 13 -2
# 14 age
# 15 -2
# 16 age
# 17 -2
# 18 age
# 19 -2
# 20 -2
# 12 sex
# 21 -2
# 22 -2
# 10 age
# 23 -2
# 24 hours-per-week
# 25 -2
# 26 -2
# 6 age
# 27 capital-loss
# 29 hours-per-week
# 31 -2
# 32 occupation=Prof-specialty
# 33 -2
# 34 hours-per-week
# 35 -2
# 36 -2
# 30 -2
# 28 age
# 37 education-num
# 39 age
# 41 age
# 43 race
# 45 -2
# 46 hours-per-week
# 47 -2
# 48 -2
# 44 -2
# 42 -2
# 40 -2
# 38 capital-gain
# 49 education-num
# 51 hours-per-week
# 53 relationship=Other-relative
# 55 workclass=Federal-gov
# 57 occupation=Sales
# 59 -2
# 60 age
# 61 -2
# 62 age
# 63 -2
# 64 -2
# 58 age
# 65 -2
# 66 -2
# 56 -2
# 54 hours-per-week
# 67 -2
# 68 -2
# 52 age
# 69 -2
# 70 -2
# 50 -2
# 4 -2
# 2 capital-gain
# 71 education-num
# 73 hours-per-week
# 75 capital-loss
# 77 education-num
# 79 native-country=El-Salvador
# 81 occupation=Transport-moving
# 83 -2
# 84 education-num
# 85 -2
# 86 -2
# 82 -2
# 80 hours-per-week
# 87 -2
# 88 workclass=Self-emp-inc
# 89 age
# 91 age
# 93 workclass=Federal-gov
# 95 occupation=Exec-managerial
# 97 occupation=Adm-clerical
# 99 age
# 101 occupation=Tech-support
# 103 sex
# 105 -2
# 106 occupation=Sales
# 107 hours-per-week
# 109 -2
# 110 age
# 111 -2
# 112 age
# 113 -2
# 114 age
# 115 occupation=Craft-repair
# 117 -2
# 118 age
# 119 -2
# 120 -2
# 116 native-country=Mexico
# 121 occupation=Craft-repair
# 123 -2
# 124 age
# 125 -2
# 126 -2
# 122 -2
# 108 age
# 128 age
# 130 -2
# 131 -2
# 129 -2
# 104 -2
# 102 capital-gain
# 132 -2
# 133 -2
# 100 relationship=Wife
# 134 -2
# 135 -2
# 98 age
# 136 -2
# 137 -2
# 96 -2
# 94 -2
# 92 hours-per-week
# 138 age
# 140 age
# 142 sex
# 144 -2
# 145 occupation=Handlers-cleaners
# 146 -2
# 147 -2
# 143 -2
# 141 race
# 148 -2
# 149 -2
# 139 -2
# 90 -2
# 78 age
# 150 -2
# 151 -2
# 76 workclass=Self-emp-not-inc
# 152 age
# 154 age
# 156 occupation=Transport-moving
# 158 age
# 160 hours-per-week
# 162 occupation=Craft-repair
# 164 education-num
# 166 -2
# 167 -2
# 165 -2
# 163 -2
# 161 -2
# 159 -2
# 157 hours-per-week
# 168 education=7th-8th
# 170 -2
# 171 -2
# 169 occupation=Transport-moving
# 172 -2
# 173 -2
# 155 age
# 174 -2
# 175 -2
# 153 age
# 176 race
# 178 age
# 180 -2
# 181 -2
# 179 -2
# 177 age
# 182 -2
# 183 -2
# 74 capital-loss
# 184 occupation=Prof-specialty
# 186 education-num
# 188 capital-gain
# 190 capital-gain
# 192 occupation=Sales
# 194 education=Assoc-voc
# 196 age
# 198 -2
# 199 race
# 200 native-country=United-States
# 202 hours-per-week
# 204 -2
# 205 -2
# 203 age
# 206 -2
# 207 -2
# 201 hours-per-week
# 208 age
# 210 -2
# 211 hours-per-week
# 212 -2
# 213 workclass=State-gov
# 214 -2
# 215 age
# 216 -2
# 217 -2
# 209 education=Assoc-acdm
# 218 age
# 220 age
# 222 education-num
# 224 native-country=United-States
# 226 -2
# 227 age
# 228 workclass=Self-emp-not-inc
# 230 occupation=Protective-serv
# 232 -2
# 233 age
# 234 -2
# 235 -2
# 231 -2
# 229 hours-per-week
# 236 -2
# 237 -2
# 225 age
# 238 -2
# 239 -2
# 223 workclass=Self-emp-inc
# 240 workclass=Self-emp-not-inc
# 242 age
# 244 education-num
# 246 hours-per-week
# 248 -2
# 249 age
# 250 -2
# 251 -2
# 247 -2
# 245 workclass=Private
# 252 -2
# 253 age
# 254 occupation=Exec-managerial
# 256 age
# 258 -2
# 259 education-num
# 260 -2
# 261 -2
# 257 -2
# 255 -2
# 243 -2
# 241 -2
# 221 age
# 262 age
# 264 education-num
# 266 -2
# 267 -2
# 265 -2
# 263 workclass=Self-emp-inc
# 268 occupation=Craft-repair
# 270 workclass=State-gov
# 272 hours-per-week
# 274 age
# 276 hours-per-week
# 278 -2
# 279 -2
# 277 -2
# 275 age
# 280 -2
# 281 age
# 282 -2
# 283 -2
# 273 -2
# 271 workclass=State-gov
# 284 -2
# 285 -2
# 269 -2
# 219 -2
# 197 age
# 286 age
# 288 -2
# 289 hours-per-week
# 290 -2
# 291 -2
# 287 -2
# 195 education-num
# 292 hours-per-week
# 294 -2
# 295 hours-per-week
# 296 hours-per-week
# 298 age
# 300 -2
# 301 age
# 302 -2
# 303 age
# 304 -2
# 305 age
# 306 -2
# 307 -2
# 299 -2
# 297 -2
# 293 -2
# 193 -2
# 191 -2
# 189 occupation=Tech-support
# 308 native-country=India
# 310 -2
# 311 -2
# 309 -2
# 187 education-num
# 312 -2
# 313 age
# 314 education-num
# 316 -2
# 317 age
# 318 age
# 320 -2
# 321 race
# 322 -2
# 323 -2
# 319 hours-per-week
# 324 sex
# 326 -2
# 327 -2
# 325 -2
# 315 native-country=Canada
# 328 hours-per-week
# 330 age
# 332 -2
# 333 age
# 334 education-num
# 336 sex
# 338 -2
# 339 -2
# 337 -2
# 335 age
# 340 -2
# 341 age
# 342 workclass=Private
# 344 -2
# 345 -2
# 343 education=Masters
# 346 -2
# 347 hours-per-week
# 348 -2
# 349 -2
# 331 age
# 350 -2
# 351 age
# 352 -2
# 353 -2
# 329 -2
# 185 hours-per-week
# 354 education-num
# 356 -2
# 357 age
# 358 -2
# 359 -2
# 355 -2
# 72 age
# 360 -2
# 361 -2
